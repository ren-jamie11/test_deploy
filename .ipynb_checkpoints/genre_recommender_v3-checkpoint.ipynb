# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
import time

import warnings
warnings.filterwarnings('ignore')

# %%
genres = ['Art',
 'Biography',
 'Business',
 'Chick Lit',
 "Children's",
 'Christian',
 'Classics',
 'Comics',
 'Contemporary',
 'Cookbooks',
 'Crime',
 'Ebooks',
 'Fantasy',
 'Fiction',
 'Gay and Lesbian',
 'Graphic Novels',
 'Historical Fiction',
 'History',
 'Horror',
 'Humor and Comedy',
 'Manga',
 'Memoir',
 'Music',
 'Mystery',
 'Nonfiction',
 'Paranormal',
 'Philosophy',
 'Poetry',
 'Psychology',
 'Religion',
 'Romance',
 'Science',
 'Science Fiction',
 'Self Help',
 'Suspense',
 'Spirituality',
 'Sports',
 'Thriller',
 'Travel',
 'Young Adult']

def get_user_genre_counts(reviews):
    
    user_genre_counts = reviews.groupby('user_id')[genres].sum().T  # genres as index
    num_reviews_by_user = reviews.groupby('user_id')['title'].count()
    user_genre_pct = user_genre_counts.div(num_reviews_by_user, axis = 1)

    return user_genre_counts, user_genre_pct

genre_labels = pd.read_parquet("data/genre_labels.parquet")
all_labeled_reviews = pd.read_parquet("data/all_labeled_reviews.parquet")
user_genre_counts, user_genre_pct = get_user_genre_counts(all_labeled_reviews)
compact_user_genre_pct = pd.read_parquet("data/compact_user_genre_pct.parquet")
main_user_item_matrix = pd.read_parquet("data/main_user_item_matrix.parquet")

# %%
all_books = pd.read_parquet("data/all_books.parquet")
all_books['publish_date'] = all_books['publish_date'].str[:-6]
all_books = all_books.drop_duplicates(subset = ['author', 'publish_date', 'rating'])
all_books_ratings = all_books[['title', 'rating', 'num_ratings']]
books_author_date = all_books[['title', 'author', 'publish_date']]
books_author_date = books_author_date.set_index('title')

users_data = pd.read_parquet("data/users_data.parquet")

# %%
def construct_user_item_matrix(reviews):
    reviews_grouped = reviews.groupby(['user_id', 'title'])['rating'].mean().reset_index()
    user_item_matrix = reviews_grouped.pivot(index='user_id', columns='title', values='rating')
    user_item_matrix = user_item_matrix.fillna(0)

    return user_item_matrix

def center_user_item_matrix(user_item_matrix):
    """ Assumes users are rows
        Subtracts each user's rating by its mean ratings 
        (computed from non zero ratings)
    """
    
    tmp = user_item_matrix.replace(0, np.NaN)
    tmp_means = tmp.mean(axis = 1)

    new_tmp = tmp.sub(tmp_means, axis = 0)
    new_tmp = new_tmp.fillna(0)

    return new_tmp

# %%
def get_expert_user_item_matrix(user_item_matrix, experts):
    expert_user_item_matrix =  user_item_matrix[user_item_matrix.index.isin(experts)]
    expert_user_item_matrix = expert_user_item_matrix.loc[experts]

    return expert_user_item_matrix

def get_expert_ratings(expert_user_item_matrix, top_n_reviewers):
    """ sum(amount of say * rating) for everyone who rated the book for each book
    
    The more people who interacted...the more the score will be affected
    E.g. 10 people who rated positive > 5 people who rated positive
    """
    amount_of_say = top_n_reviewers['score_normed']

    expert_ratings = expert_user_item_matrix.T.dot(amount_of_say)
    expert_ratings= pd.DataFrame(expert_ratings)
    
    expert_ratings.columns = ['expert_metric']
    expert_ratings = expert_ratings.drop_duplicates()
    expert_ratings = expert_ratings.sort_values(by = 'expert_metric', ascending = False)

    return expert_ratings

def lookup_rating(user_item_matrix, user_id, book_name):
    return user_item_matrix.loc[user_id, book_name]

def ratings_of_those_who_read(book_name, top_n_reviewers, expert_user_item_matrix):
    experts = top_n_reviewers.index
    amount_of_say = top_n_reviewers['score_normed']
    
    wavgs = pd.DataFrame(amount_of_say)
    wavgs['book_rating'] = [lookup_rating(expert_user_item_matrix, u, book_name) for u in experts]
    wavgs = wavgs[wavgs.book_rating != 0]

    return wavgs

def avg_expert_rating(book_name, top_n_reviewers, expert_user_item_matrix):
    amount_of_say = top_n_reviewers['score_normed']
    experts = top_n_reviewers.index
    
    wavgs = ratings_of_those_who_read(book_name, top_n_reviewers, expert_user_item_matrix)
    res = np.dot(wavgs['score_normed'], wavgs['book_rating'])/np.sum(wavgs['score_normed'])
    
    return res, len(wavgs)

# %%
def get_score(count, pct, alpha = 1):
    score = count * pct**alpha
    return score

def min_max_scale(series, max_value = 100):
    min_val = series.min()
    max_val = series.max()
    return ((series - min_val) / (max_val - min_val)) * max_value

def normalize_series(series):
    mean = series.mean()
    std = series.std()
    return (series - mean) / std

def label_reviews_with_genre(all_reviews, genre_labels):
    all_labeled_reviews = all_reviews.merge(
        genre_labels, 
        on='title', 
        how='inner'
    )

    all_labeled_reviews = all_labeled_reviews.drop_duplicates(subset=['title', 'user_id', 'rating'])
    return all_labeled_reviews

def user_read_counts_for_genre(my_genre, user_genre_counts, user_genre_pct):
    genre_review_count_ranked = user_genre_counts.loc[my_genre, :].sort_values(ascending = False)
    genre_pct_of_reviews_ranked = user_genre_pct.loc[my_genre, :].sort_values(ascending = False)

    res = pd.DataFrame({"review_count": genre_review_count_ranked, "review_pct": genre_pct_of_reviews_ranked})
    return res

def get_genre_ranker(my_genre, user_genre_counts, user_genre_pct, alpha = 1, allowed = main_user_item_matrix.index):
    """ Ranks all reviewers for a genre in a df

    Schema
    ---------------------------------------------------
    user_id  | review_count   review_pct   score
    ----------------------------------------------------

    review_count: How many books have they reviewed from this genre?
    review_pct: What % of the books they've reviewed are from this genre?
    score: Weighted combination of count and pct (count * pct ** alpha) 
    
    """
    
    user_read_counts = user_read_counts_for_genre(my_genre, user_genre_counts, user_genre_pct)
    user_read_counts['score'] = get_score(user_read_counts['review_count'], user_read_counts['review_pct'], alpha = alpha)

    user_read_counts = user_read_counts[user_read_counts.review_count > 0]
    user_read_counts = user_read_counts.sort_values(by = 'score', ascending = False)

    user_read_counts = user_read_counts[user_read_counts.index.isin(allowed)]
    
    return user_read_counts

def get_top_n_reviewers(ranker, n):
    n = min(n, len(ranker))
    print("n", n)
    top_n = ranker.head(n)
    top_n['score_normed'] = top_n['score']/np.sum(top_n['score'])

    return top_n

def get_user_genre_counts_and_pcts(user_reviews, genre_labels = genre_labels):
    this_user_reviews_labeled = label_reviews_with_genre(user_reviews, genre_labels)
    this_user_genre_counts, this_user_genre_pct = get_user_genre_counts(this_user_reviews_labeled)

    return this_user_genre_counts, this_user_genre_pct

def get_user_similarities_ranker_by_genre(this_user_genre_pct, alpha, min_similarity = 0.8, user_genre_counts = user_genre_counts, 
                                          other_users_genre_pct = compact_user_genre_pct):
    # construct matrix
    M = other_users_genre_pct.values
    v = this_user_genre_pct.values
    similarities = cosine_similarity(M.T, v.T).ravel()
    other_users = other_users_genre_pct.T.index
    similarity_ranker = pd.DataFrame({'other_users': other_users, 'genre_similarity': similarities})
    
    # Formatting the similarity table
    similarity_ranker = similarity_ranker.set_index("other_users")
    similarity_ranker['read_count'] = user_genre_counts.sum(axis = 0)
    similarity_ranker = similarity_ranker[similarity_ranker.genre_similarity >= min_similarity]
    similarity_ranker['score'] = get_score(similarity_ranker['read_count'], similarity_ranker['genre_similarity'], alpha = alpha)
    similarity_ranker = similarity_ranker.sort_values(by = 'score', ascending = False) 
    
    return similarity_ranker


def get_author_for_recs(recs, books_author_date = books_author_date):
    assert recs.index.name == 'title', "Recs index must be title"
    assert books_author_date.index.name == 'title', "books/author df index must be title"
    
    recs = recs.merge(books_author_date, left_index = True, right_index = True)
    author_col = recs.pop('author')
    recs.insert(0, 'author', author_col)
    
    return recs

def recommend_books_by_user_genre_reading_pattern_similarity(user_reviews, novelty_factor, alpha = 250, genre_labels = genre_labels):
    # get similar users
    this_user_genre_counts, this_user_genre_pct = get_user_genre_counts_and_pcts(user_reviews, genre_labels = genre_labels)
    genre_similarity_ranker = get_user_similarities_ranker_by_genre(this_user_genre_pct, alpha = alpha)

    recommended_books, neighbors = get_recommendation_from_top(genre_similarity_ranker, novelty_factor)
    recommended_books = recommended_books[~recommended_books.index.isin(user_reviews.title.values)]
    
    return recommended_books, neighbors

""" USE THIS FOR CUSTOME GENRE PCT"""
def recommend_books_by_custom_genre_pct(custom_user_genre_pct, novelty_factor, alpha = 250):
    genre_similarity_ranker = get_user_similarities_ranker_by_genre(custom_user_genre_pct, alpha = alpha)
    
    recommended_books, neighbors = get_recommendation_from_top(genre_similarity_ranker, novelty_factor)
    recommended_books = recommended_books[~recommended_books.index.isin(user_reviews.title.values)]
    
    return recommended_books, neighbors

# %%
def get_url_from_user_id(user_id):
    user_row = users_data[users_data.user_id == user_id]
    if user_row:
        url = user_row['user_url'].values[0]
        return url

    return "user url not found..."

def get_book_scores_from_experts(user_item_matrix, rating_emphasis):
    """
    Given a user-item rating matrix with users as rows and book titles as columns,
    returns a DataFrame with the mean rating and number of ratings per book,
    ignoring zero entries.
    """

    masked = user_item_matrix.mask(user_item_matrix == 0)
    
    avg_ratings = masked.mean(axis=0)
    rating_counts = masked.count(axis=0)

    book_stats = pd.DataFrame({
        "rating": avg_ratings,
        "count": rating_counts
    })

    book_stats = book_stats.dropna(subset=["rating"])
    book_stats['score'] = get_score(book_stats['count'], book_stats['rating'], alpha = rating_emphasis)
    book_stats['score'] = min_max_scale(book_stats['score']).round(1)
    book_stats = book_stats.sort_values(by="score", ascending=False)
    book_stats = book_stats[['score', 'rating', "count"]]

    return book_stats

def merge_expert_with_overall(expert_rating, all_books_rating, num_reviewers):
    merged = expert_rating.merge(all_books_ratings, left_index=True, right_on='title', how='inner')
    merged = merged.set_index('title')
    
    return merged

def format_thousands(series):
    """
    Convert integers to strings formatted in thousands with 'k' suffix.
    Examples:
        12345 -> '12.3k'
        24992 -> '25k'
        300   -> '0.3k'
    """
    return series.apply(lambda x: f"{x/1000:.1f}k".rstrip('0').rstrip('.'))

def filter_book_recs_by_score_or_n(df, n, min_score):
    high_score_books = df[df.score >= min_score]
    if len(high_score_books) >= n:
        return high_score_books.head(n)

    return high_score_books


def get_bin_labels(arr, width = 0.001):
    quantiles = np.arange(0.1, 1.0, width)
    quantile_values = np.quantile(arr, quantiles)

    bin_indices = np.digitize(arr, quantile_values, right=True)
    bin_indices = np.clip(bin_indices, 0, len(quantiles) - 1)
    bin_labels = quantiles[bin_indices].round(2)

    return bin_labels


def enrich_books_with_metadata(recommended_books, book_ratings = all_books_ratings, metadata = books_author_date):
    merged = recommended_books.merge(book_ratings, left_index=True, right_on='title', how='inner')
    merged = merged.set_index('title').rename(columns = {'rating_x': 'rating', 'rating_y': 'overall_rating'})
    merged_with_book_data = pd.merge(metadata, merged, left_index = True, right_index = True, how = 'right')

    return merged_with_book_data


def post_process_books(recommended_books, n = 50):
    recommended_books = recommended_books[['author', 'publish_date', 'adjusted_score','rating', 'count', 'novelty', 'overall_rating', 'num_ratings']] 
    recommended_books.columns = ['author', 'published', 'score','rating', 'count', 'novelty', 'goodreads rating', 'ratings']
    # recommended_books = recommended_books.drop_duplicates(subset = ['author', 'published', 'goodreads rating'])
    recommended_books['score'] = recommended_books['score'].round(1) 
    recommended_books['rating'] = recommended_books['rating'].round(1) 
    recommended_books['goodreads rating'] = recommended_books['goodreads rating'].round(1) 
    recommended_books['ratings'] = format_thousands(recommended_books['ratings'])

    return recommended_books.head(50).sort_values(by = 'score', ascending = False)

def post_process_neighbors(neighbors, users_data = users_data):
    user_cols = ['name','genre_similarity', 'read_count']

    m_neighbors = pd.merge(neighbors, users_data, left_index = True, right_on = "user_id", how = "left")
    m_neighbors['genre_similarity'] = m_neighbors['genre_similarity'].round(3) 
    m_neighbors = m_neighbors.set_index('user_id')
    m_neighbors = m_neighbors[user_cols]

    m_neighbors.columns = ['name', 'genre similarity', 'review samples']
    
    return m_neighbors

def get_recommendation_from_top(ranker, novelty_factor, user_item_matrix = main_user_item_matrix,
                                num_reviewers = 100, rating_emphasis = 2, min_similarity = 0.85):
    
    top_n = get_top_n_reviewers(ranker, num_reviewers)
    top_n = top_n[top_n.genre_similarity >= min_similarity]
    experts = top_n.index
    neighbors = post_process_neighbors(top_n.head(num_reviewers))
    
    # user_item_matrix for top reviewers of this genre
    expert_user_item_matrix = get_expert_user_item_matrix(user_item_matrix, experts)
    expert_ratings = get_book_scores_from_experts(expert_user_item_matrix, rating_emphasis)

    rec_books_with_metadata = enrich_books_with_metadata(expert_ratings)
    rec_books_with_metadata['novelty'] = get_bin_labels(rec_books_with_metadata.num_ratings.values)
    rec_books_with_metadata['novelty'] = np.abs(1 - rec_books_with_metadata['novelty'])
    rec_books_with_metadata['adjusted_score'] = get_score(count = rec_books_with_metadata['score'],
                                                          pct = rec_books_with_metadata['novelty'],
                                                          alpha = novelty_factor)
    
    rec_books_with_metadata['adjusted_score'] = min_max_scale(rec_books_with_metadata['adjusted_score'])
    best_books = post_process_books(rec_books_with_metadata)

    
    return best_books, neighbors

# %%
user_reviews = pd.read_parquet("data/jamie_reviews.parquet")
this_user_genre_counts, this_user_genre_pct = get_user_genre_counts_and_pcts(user_reviews, genre_labels = genre_labels)
genre_similarity_ranker = get_user_similarities_ranker_by_genre(this_user_genre_counts, alpha = 250)

start = time.time()
recommended_books, neighbors = recommend_books_by_custom_genre_pct(this_user_genre_pct, novelty_factor = .1)
end = time.time()
print(f"Elapsed, {(end - start):.2f} seconds")
# Out:
# n 100
# Elapsed, 0.35 seconds

# %%
recommended_books
# Out:
#                                                                                   author  \
# title
# The Art of Travel                                                        Alain de Botton
# Justice: What's the Right Thing to Do?                                 Michael J. Sandel
# How We Survived Communism and Even Laughed                             Slavenka Drakulić
# The Brothers Karamazov                                                 Fyodor Dostoevsky
# Goals!: How to Get Everything You Want Faster T...                           Brian Tracy
# The Consolations of Philosophy                                           Alain de Botton
# The Shallows: What the Internet is Doing to Our...                         Nicholas Carr
# The Orange Girl                                                          Jostein Gaarder
# The 7 Habits of Highly Effective People: Powerf...                      Stephen R. Covey
# Man’s Search for Meaning                                                Viktor E. Frankl
# To Have or To Be?                                                            Erich Fromm
# Status Anxiety                                                           Alain de Botton
# Dead Souls                                                                 Nikolai Gogol
# Zen Mind, Beginner's Mind: Informal Talks on Ze...                        Shunryu Suzuki
# The Psychology of Money                                                    Morgan Housel
# Shakespeare's Sonnets                                                William Shakespeare
# Shoe Dog: A Memoir by the Creator of Nike                                    Phil Knight
# A Thousand Splendid Suns                                                 Khaled Hosseini
# The Merchant of Venice                                               William Shakespeare
# Recursion                                                                   Blake Crouch
# What I Talk About When I Talk About Running                              Haruki Murakami
# Immortality                                                                Milan Kundera
# The Dream of a Ridiculous Man                                          Fyodor Dostoevsky
# The Razor’s Edge                                                     W. Somerset Maugham
# Brief Answers to the Big Questions                                       Stephen Hawking
# The Compound Effect: Jumpstart Your Income, You...                          Darren Hardy
# The Epic of Gilgamesh                                                          Anonymous
# Influence: The Psychology of Persuasion                               Robert B. Cialdini
# King Lear                                                            William Shakespeare
# The Lessons of History                                                       Will Durant
# Talking to My Daughter About the Economy: or, H...                      Yanis Varoufakis
# The Count of Monte Cristo                                                Alexandre Dumas
# Sophie's World                                                           Jostein Gaarder
# Why We Sleep: Unlocking the Power of Sleep and ...                        Matthew Walker
# A Guide to the Good Life: The Ancient Art of St...                     William B. Irvine
# The Joke                                                                   Milan Kundera
# Dear Life                                                                    Alice Munro
# Show Your Work!: 10 Ways to Share Your Creativi...                          Austin Kleon
# Escape from Camp 14: One Man's Remarkable Odyss...                         Blaine Harden
# Eat That Frog!: 21 Great Ways to Stop Procrasti...                           Brian Tracy
# Ikigai: The Japanese Secret to a Long and Happy...                        Héctor  García
# The Obstacle Is the Way: The Timeless Art of Tu...                          Ryan Holiday
# Tao Te Ching: A New English Version                                              Lao Tzu
# Freakonomics: A Rogue Economist Explores the Hi...                      Steven D. Levitt
# Freakonomics - A Rogue Economist Explores The H...  Stephen J. Levitt, Steven D.; Dubner
# Homo Deus: A History of Tomorrow                                       Yuval Noah Harari
# Atomic Habits: An Easy & Proven Way to Build Go...                           James Clear
#
#                                                    published  score  rating  \
# title
# The Art of Travel                                       2002  100.0     4.5
# Justice: What's the Right Thing to Do?                  2007   74.0     4.8
# How We Survived Communism and Even Laughed              1991   69.4     4.5
# The Brothers Karamazov                                  1880   69.0     5.0
# Goals!: How to Get Everything You Want Faster T...      1989   67.5     4.5
# The Consolations of Philosophy                          2000   65.3     3.7
# The Shallows: What the Internet is Doing to Our...      2010   64.9     4.0
# The Orange Girl                                         2003   64.5     4.0
# The 7 Habits of Highly Effective People: Powerf...      1989   63.6     5.0
# Man’s Search for Meaning                                1946   61.0     4.0
# To Have or To Be?                                       1976   60.5     4.2
# Status Anxiety                                          2004   59.4     4.2
# Dead Souls                                              1842   57.5     5.0
# Zen Mind, Beginner's Mind: Informal Talks on Ze...      1970   57.3     4.2
# The Psychology of Money                                 2020   57.3     4.5
# Shakespeare's Sonnets                                   1609   56.6     5.0
# Shoe Dog: A Memoir by the Creator of Nike               2016   56.3     4.5
# A Thousand Splendid Suns                                2007   55.4     5.0
# The Merchant of Venice                                  1596   54.2     5.0
# Recursion                                               2019   52.6     5.0
# What I Talk About When I Talk About Running             2007   52.5     4.2
# Immortality                                             1990   52.1     4.7
# The Dream of a Ridiculous Man                           1877   51.4     4.0
# The Razor’s Edge                                        1944   51.1     3.6
# Brief Answers to the Big Questions                      2018   50.4     4.7
# The Compound Effect: Jumpstart Your Income, You...      2010   50.0     4.0
# The Epic of Gilgamesh                                   1201   49.2     4.7
# Influence: The Psychology of Persuasion                 1984   48.0     4.7
# King Lear                                               1605   46.8     4.7
# The Lessons of History                                  1997   46.4     4.3
# Talking to My Daughter About the Economy: or, H...      2013   46.3     4.3
# The Count of Monte Cristo                               1846   46.2     5.0
# Sophie's World                                          1991   46.1     4.7
# Why We Sleep: Unlocking the Power of Sleep and ...      2017   45.9     4.0
# A Guide to the Good Life: The Ancient Art of St...      2008   45.8     3.8
# The Joke                                                1967   44.9     4.3
# Dear Life                                               2011   44.9     4.3
# Show Your Work!: 10 Ways to Share Your Creativi...      2014   44.1     4.3
# Escape from Camp 14: One Man's Remarkable Odyss...      2012   43.7     3.8
# Eat That Frog!: 21 Great Ways to Stop Procrasti...      2001   43.4     3.8
# Ikigai: The Japanese Secret to a Long and Happy...      2016   43.1     3.8
# The Obstacle Is the Way: The Timeless Art of Tu...      2014   42.8     3.8
# Tao Te Ching: A New English Version                      351   41.3     4.3
# Freakonomics: A Rogue Economist Explores the Hi...      2005   40.1     4.7
# Freakonomics - A Rogue Economist Explores The H...      2005   40.1     4.7
# Homo Deus: A History of Tomorrow                        2015   39.6     4.3
# Atomic Habits: An Easy & Proven Way to Build Go...      2018   33.1     4.3
#
#                                                     count  novelty  \
# title
# The Art of Travel                                       6     0.52
# Justice: What's the Right Thing to Do?                  4     0.51
# How We Survived Communism and Even Laughed              4     0.81
# The Brothers Karamazov                                  4     0.09
# Goals!: How to Get Everything You Want Faster T...      4     0.61
# The Consolations of Philosophy                          6     0.46
# The Shallows: What the Internet is Doing to Our...      5     0.47
# The Orange Girl                                         5     0.44
# The 7 Habits of Highly Effective People: Powerf...      4     0.04
# Man’s Search for Meaning                                6     0.04
# To Have or To Be?                                       4     0.66
# Status Anxiety                                          4     0.55
# Dead Souls                                              3     0.27
# Zen Mind, Beginner's Mind: Informal Talks on Ze...      4     0.38
# The Psychology of Money                                 4     0.12
# Shakespeare's Sonnets                                   3     0.23
# Shoe Dog: A Memoir by the Creator of Nike               4     0.10
# A Thousand Splendid Suns                                4     0.01
# The Merchant of Venice                                  3     0.15
# Recursion                                               3     0.11
# What I Talk About When I Talk About Running             4     0.16
# Immortality                                             3     0.41
# The Dream of a Ridiculous Man                           4     0.44
# The Razor’s Edge                                        5     0.37
# Brief Answers to the Big Questions                      3     0.29
# The Compound Effect: Jumpstart Your Income, You...      4     0.33
# The Epic of Gilgamesh                                   3     0.23
# Influence: The Psychology of Persuasion                 3     0.18
# King Lear                                               3     0.14
# The Lessons of History                                  3     0.58
# Talking to My Daughter About the Economy: or, H...      3     0.57
# The Count of Monte Cristo                               3     0.03
# Sophie's World                                          3     0.12
# Why We Sleep: Unlocking the Power of Sleep and ...      4     0.14
# A Guide to the Good Life: The Ancient Art of St...      4     0.51
# The Joke                                                3     0.42
# Dear Life                                               3     0.42
# Show Your Work!: 10 Ways to Share Your Creativi...      3     0.35
# Escape from Camp 14: One Man's Remarkable Odyss...      4     0.32
# Eat That Frog!: 21 Great Ways to Stop Procrasti...      4     0.30
# Ikigai: The Japanese Secret to a Long and Happy...      4     0.28
# The Obstacle Is the Way: The Timeless Art of Tu...      4     0.26
# Tao Te Ching: A New English Version                     3     0.18
# Freakonomics: A Rogue Economist Explores the Hi...      3     0.03
# Freakonomics - A Rogue Economist Explores The H...      3     0.03
# Homo Deus: A History of Tomorrow                        3     0.12
# Atomic Habits: An Easy & Proven Way to Build Go...      3     0.02
#
#                                                     goodreads rating  ratings
# title
# The Art of Travel                                                3.8    25.2k
# Justice: What's the Right Thing to Do?                           4.3    26.5k
# How We Survived Communism and Even Laughed                       4.1     5.2k
# The Brothers Karamazov                                           4.4   361.8k
# Goals!: How to Get Everything You Want Faster T...               4.2    15.5k
# The Consolations of Philosophy                                   4.0    32.7k
# The Shallows: What the Internet is Doing to Our...               3.9    31.8k
# The Orange Girl                                                  3.9    35.2k
# The 7 Habits of Highly Effective People: Powerf...               4.2   792.1k
# Man’s Search for Meaning                                         4.4   811.1k
# To Have or To Be?                                                4.2    12.8k
# Status Anxiety                                                   3.9    20.9k
# Dead Souls                                                       4.0    91.7k
# Zen Mind, Beginner's Mind: Informal Talks on Ze...               4.2    48.2k
# The Psychology of Money                                          4.3   266.7k
# Shakespeare's Sonnets                                            4.2   109.6k
# Shoe Dog: A Memoir by the Creator of Nike                        4.5   341.9k
# A Thousand Splendid Suns                                         4.4  1653.2k
# The Merchant of Venice                                           3.8   197.4k
# Recursion                                                        4.2   280.0k
# What I Talk About When I Talk About Running                      3.9   189.2k
# Immortality                                                      4.1    41.4k
# The Dream of a Ridiculous Man                                    4.0    35.6k
# The Razor’s Edge                                                 4.2    51.7k
# Brief Answers to the Big Questions                               4.3    82.4k
# The Compound Effect: Jumpstart Your Income, You...               4.2    63.2k
# The Epic of Gilgamesh                                            3.8   112.6k
# Influence: The Psychology of Persuasion                          4.2   167.8k
# King Lear                                                        3.9   230.1k
# The Lessons of History                                           4.1    19.1k
# Talking to My Daughter About the Economy: or, H...               4.1    19.5k
# The Count of Monte Cristo                                        4.3   976.8k
# Sophie's World                                                   4.0   272.7k
# Why We Sleep: Unlocking the Power of Sleep and ...               4.4   210.8k
# A Guide to the Good Life: The Ancient Art of St...               4.2    26.3k
# The Joke                                                         4.0    38.7k
# Dear Life                                                        3.8    39.3k
# Show Your Work!: 10 Ways to Share Your Creativi...               4.1    56.6k
# Escape from Camp 14: One Man's Remarkable Odyss...               4.0    70.3k
# Eat That Frog!: 21 Great Ways to Stop Procrasti...               3.9    78.8k
# Ikigai: The Japanese Secret to a Long and Happy...               3.8    83.5k
# The Obstacle Is the Way: The Timeless Art of Tu...               4.2    93.7k
# Tao Te Ching: A New English Version                              4.3   173.6k
# Freakonomics: A Rogue Economist Explores the Hi...               4.0   879.8k
# Freakonomics - A Rogue Economist Explores The H...               4.0   879.9k
# Homo Deus: A History of Tomorrow                                 4.2   274.4k
# Atomic Habits: An Easy & Proven Way to Build Go...               4.3  1139.1k

# %%
neighbors
# Out:
#                                         name  genre similarity  review samples
# user_id
# 2023961-salma                          Salma             0.947              74
# 1741426-odai-al-saeed          Odai Al-Saeed             0.942             186
# 93895577-ali-karimnejad       Ali Karimnejad             0.940             115
# 10179929-sanjay                       Sanjay             0.934             217
# 25664045-gary                           Gary             0.938              58
# ...                                      ...               ...             ...
# 10999850-cathy-patton           Cathy Patton             0.880              25
# 63813795-khyati-gautam         Khyati Gautam             0.879              24
# 19993-robin                            Robin             0.878              41
# 48263884-masoud-irannejad   Masoud Irannejad             0.876              66
# 124911798-haniye-mirkamali  Haniye_Mirkamali             0.876              56
#
# [100 rows x 3 columns]

# %%
user_reviews
# Out:
#                 user_id                                         title_id  \
# 0   155041466-jamie-ren                  1052.The_Richest_Man_in_Babylon
# 1   155041466-jamie-ren       4866.How_to_Stop_Worrying_and_Start_Living
# 2   155041466-jamie-ren                     2165.The_Old_Man_and_the_Sea
# 3   155041466-jamie-ren       155054.Strange_Tales_from_a_Chinese_Studio
# 4   155041466-jamie-ren                                    61439040-1984
# 5   155041466-jamie-ren                     51893.Thus_Spoke_Zarathustra
# 6   155041466-jamie-ren                            6708.The_Power_of_Now
# 7   155041466-jamie-ren                       857333.The_Art_of_Learning
# 8   155041466-jamie-ren               612188.Memories_Dreams_Reflections
# 9   155041466-jamie-ren                        24830.The_Illustrated_Man
# 10  155041466-jamie-ren                      30013.Prelude_to_Foundation
# 11  155041466-jamie-ren                          13079982-fahrenheit-451
# 12  155041466-jamie-ren                        1303.The_48_Laws_of_Power
# 13  155041466-jamie-ren                                 28862.The_Prince
# 14  155041466-jamie-ren                                  4214.Life_of_Pi
# 15  155041466-jamie-ren                           202897.Foreign_Affairs
# 16  155041466-jamie-ren                                 11989.The_Plague
# 17  155041466-jamie-ren         4865.How_to_Win_Friends_Influence_People
# 18  155041466-jamie-ren                              375802.Ender_s_Game
# 19  155041466-jamie-ren                      5107.The_Catcher_in_the_Rye
# 20  155041466-jamie-ren                             10534.The_Art_of_War
# 21  155041466-jamie-ren                             5129.Brave_New_World
# 22  155041466-jamie-ren                               49552.The_Stranger
# 23  155041466-jamie-ren                    4069.Man_s_Search_for_Meaning
# 24  155041466-jamie-ren                        7144.Crime_and_Punishment
# 25  155041466-jamie-ren                                    44767458-dune
# 26  155041466-jamie-ren                      12609433-the-power-of-habit
# 27  155041466-jamie-ren                             18007564-the-martian
# 28  155041466-jamie-ren             18143977-all-the-light-we-cannot-see
# 29  155041466-jamie-ren                              17354208-relentless
# 30  155041466-jamie-ren               24583.The_Adventures_of_Tom_Sawyer
# 31  155041466-jamie-ren                       91950.The_Myth_of_Sisyphus
# 32  155041466-jamie-ren                       30257963-12-rules-for-life
# 33  155041466-jamie-ren                                35133922-educated
# 34  155041466-jamie-ren                39330937-the-laws-of-human-nature
# 35  155041466-jamie-ren                     40230101-the-mamba-mentality
# 36  155041466-jamie-ren                           41721428-can-t-hurt-me
# 37  155041466-jamie-ren                                   41795733-range
# 38  155041466-jamie-ren  43708884-the-boy-the-mole-the-fox-and-the-horse
# 39  155041466-jamie-ren                           50093704-in-five-years
#
#                                                 title  rating  votes
# 0                          The Richest Man in Babylon       4      0
# 1   How to Stop Worrying and Start Living: Time-Te...       4      0
# 2                             The Old Man and the Sea       5      0
# 3                 Strange Tales from a Chinese Studio       5      0
# 4                                                1984       5      0
# 5                              Thus Spoke Zarathustra       4      0
# 6   The Power of Now: A Guide to Spiritual Enlight...       5      0
# 7   The Art of Learning: A Journey in the Pursuit ...       5      0
# 8                       Memories, Dreams, Reflections       5      0
# 9                                 The Illustrated Man       4      0
# 10                              Prelude to Foundation       5      0
# 11                                     Fahrenheit 451       5      0
# 12                               The 48 Laws of Power       4      0
# 13                                         The Prince       4      0
# 14                                         Life of Pi       4      0
# 15                                    Foreign Affairs       4      0
# 16                                         The Plague       3      0
# 17              How to Win Friends & Influence People       5      0
# 18                                       Ender’s Game       4      0
# 19                             The Catcher in the Rye       4      0
# 20                                     The Art of War       5      0
# 21                                    Brave New World       5      0
# 22                                       The Stranger       4      0
# 23                           Man's Search for Meaning       5      0
# 24                               Crime and Punishment       4      0
# 25                                               Dune       5      0
# 26  The Power of Habit: Why We Do What We Do in Li...       5      0
# 27                                        The Martian       4      0
# 28                        All the Light We Cannot See       5      0
# 29      Relentless: From Good to Great to Unstoppable       4      0
# 30                       The Adventures of Tom Sawyer       4      0
# 31                               The Myth of Sisyphus       4      0
# 32            12 Rules for Life: An Antidote to Chaos       5      0
# 33                                           Educated       2      0
# 34                           The Laws of Human Nature       5      0
# 35                    The Mamba Mentality: How I Play       5      0
# 36  Can't Hurt Me: Master Your Mind and Defy the Odds       4      0
# 37  Range: Why Generalists Triumph in a Specialize...       4      0
# 38           The Boy, the Mole, the Fox and the Horse       5      0
# 39                                      In Five Years       4      0

# %% [markdown]
# #### Custom genre pct

# %%
this_user_genre_pct
# Out:
# user_id             155041466-jamie-ren
# Art                             0.03125
# Biography                       0.12500
# Business                        0.28125
# Chick Lit                       0.03125
# Children's                      0.00000
# Christian                       0.00000
# Classics                        0.31250
# Comics                          0.00000
# Contemporary                    0.03125
# Cookbooks                       0.00000
# Crime                           0.06250
# Ebooks                          0.00000
# Fantasy                         0.09375
# Fiction                         0.46875
# Gay and Lesbian                 0.00000
# Graphic Novels                  0.03125
# Historical Fiction              0.06250
# History                         0.12500
# Horror                          0.03125
# Humor and Comedy                0.00000
# Manga                           0.00000
# Memoir                          0.12500
# Music                           0.00000
# Mystery                         0.03125
# Nonfiction                      0.53125
# Paranormal                      0.00000
# Philosophy                      0.43750
# Poetry                          0.03125
# Psychology                      0.40625
# Religion                        0.03125
# Romance                         0.03125
# Science                         0.03125
# Science Fiction                 0.09375
# Self Help                       0.40625
# Suspense                        0.03125
# Spirituality                    0.06250
# Sports                          0.03125
# Thriller                        0.03125
# Travel                          0.00000
# Young Adult                     0.06250

# %% [markdown]
# ### Check out individual user

# %%
user_list = neighbors.head(5).index
user_list
# Out:
# Index(['2023961-salma', '1741426-odai-al-saeed', '93895577-ali-karimnejad',
#        '10179929-sanjay', '25664045-gary'],
#       dtype='object', name='user_id')

# %%
users_books = all_labeled_reviews[all_labeled_reviews.user_id.isin(user_list)]
users_books = users_books[['title', 'user_id', 'rating']]
users_books
# Out:
#                                                     title  \
# 800     Show Your Work!: 10 Ways to Share Your Creativ...
# 1124    The Lonely City: Adventures in the Art of Bein...
# 2715                       Outliers: The Story of Success
# 3485        Blink: The Power of Thinking Without Thinking
# 6953                                          Confessions
# ...                                                   ...
# 459277  Grit: Passion, Perseverance, and the Science o...
# 463509  Learned Optimism: How to Change Your Mind and ...
# 470000                                           The Road
# 470001                            Where the Crawdads Sing
# 470002                                       The Stranger
#
#                         user_id  rating
# 800             10179929-sanjay     3.0
# 1124      1741426-odai-al-saeed     4.0
# 2715    93895577-ali-karimnejad     4.0
# 3485            10179929-sanjay     3.0
# 6953      1741426-odai-al-saeed     2.0
# ...                         ...     ...
# 459277          10179929-sanjay     1.0
# 463509          10179929-sanjay     3.0
# 470000            25664045-gary     4.0
# 470001            25664045-gary     4.0
# 470002            25664045-gary     5.0
#
# [160 rows x 3 columns]

# %%
grouped_books = pd.DataFrame(users_books.groupby('title')['rating'].mean())
grouped_books['count'] = users_books.groupby('title')['rating'].count()
grouped_books = grouped_books.sort_values(by = 'rating', ascending = False)
grouped_books = grouped_books[grouped_books.rating >= 4]
grouped_books
# Out:
#                                                     rating  count
# title
# 1Q84: Book Three                                       5.0      1
# The Heart of a Dog                                     5.0      1
# The Myth of Sisyphus and Other Essays                  5.0      1
# Ham On Rye                                             5.0      1
# Ham on Rye                                             5.0      1
# ...                                                    ...    ...
# As a Man Thinketh                                      4.0      1
# Ali and Nino                                           4.0      1
# How to Stop Worrying and Start Living: Time-Tes...     4.0      1
# Relativity: The Special and the General Theory         4.0      1
# Girls of Riyadh                                        4.0      1
#
# [92 rows x 2 columns]
